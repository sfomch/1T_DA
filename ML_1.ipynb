# %%
import pandas as pd

# %%
# Загрузка данных
df_bike = pd.read_csv('data/6.1_DataSets/bikes_data.csv')
df_salary = pd.read_csv('data/6.1_DataSets/Salary_Data.csv')
df_titanic = pd.read_csv('data/6.1_DataSets/Titanic.csv')

# %%
df_bike
# Out:
#                     Company Country of Origin           Model Number of cc  \
# 0                   Aprilia             Italy          RS 660          659
# 1                   Aprilia             Italy       Tuono 660          659
# 2                   Aprilia             Italy          RS 125        124.9
# 3                   Aprilia             Italy      Shiver 900          896
# 4                   Aprilia             Italy      Tuono 1100         1077
# ..                      ...               ...             ...          ...
# 357  Energica Motor Company             Italy       EsseEsse9       110 kW
# 358  Energica Motor Company             Italy            EGO+       126 kW
# 359  Energica Motor Company             Italy  Eva Ribelle RS       126 kW
# 360             Moto Morini             Italy          X-Cape          649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½          649
#
#     Horsepower     Torque     Transmission Type     Drivetrain  \
# ...

# %%
df_bike.groupby(by=['Age', 'Job Title']).Salary.mean()

# %%
df_salary
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df_salary.groupby(by=['Job Title', 'Years of Experience']).Salary.mean()
# Out:
# Job Title                 Years of Experience
# Account Manager           5.0                     75000.000000
# Accountant                4.0                     55000.000000
# Administrative Assistant  8.0                     45000.000000
#                           10.0                    55000.000000
# Back end Developer        0.0                     53685.000000
#                                                      ...
# Web Developer             5.0                     70666.666667
#                           6.0                     77857.142857
#                           7.0                     85000.000000
#                           8.0                     90000.000000
#                           10.0                   106666.666667
# Name: Salary, Length: 738, dtype: float64

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    Male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    Male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 884          887         0       2    Male  27.0      0      0  13.0000
# 885          888         1       1  female  19.0      0      0  30.0000
# 886          889         0       3  female  60.0      1      2  23.4500
# 887          890         1       1    Male  26.0      0      0  30.0000
# 888          891         0       3    Male  32.0      0      0   7.7500
#
#      Embarked
# 0           3
# 1           1
# 2           3
# 3           3
# 4           3
# ...
